# %% [markdown]
# # Boilerplate Demographic data analyzer 👨🏻‍💻

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/adult_data.csv')
df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
df.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# salary            object
# dtype: object

# %%
 # How many of each race are represented in this dataset? 
 # This should be a Pandas series with race names as the index labels.
 
 race = df['race'].value_counts()
 race
# Out:
# race
# White                 27816
# Black                  3124
# Asian-Pac-Islander     1039
# Amer-Indian-Eskimo      311
# Other                   271
# Name: count, dtype: int64

# %%
# What is the average age of men?

male_df = df[df['sex']== 'Male']
average_age_men = male_df['age'].mean()
average_age_men
# Out:
# 39.43354749885268

# %%
# What is the percentage of people who have a Bachelor's degree?
bachelors_df = df[df['education'] == 'Bachelors']
percentage_bachelors = (bachelors_df['education'].count()/df['education'].count()) * 100
percentage_bachelors
# Out:
# 16.44605509658794

# %%
df['education'].value_counts()
# Out:
# education
# HS-grad         10501
# Some-college     7291
# Bachelors        5355
# Masters          1723
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           646
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           333
# 1st-4th           168
# Preschool          51
# Name: count, dtype: int64

# %%
    # What percentage of people with advanced education (`Bachelors`, `Masters`, or                 `Doctorate`) make more than 50K?
    # What percentage of people without advanced education make more than 50K?
    # with and without `Bachelors`, `Masters`, or `Doctorate`
advanced_education = ['Bachelors', 'Masters', 'Doctorate']
higher_df = df[df['education'].isin(advanced_education)]
higher_education_rich_percentage = (higher_df['salary'] == '>50K').mean() * 100
without_higher_df = df[~df['education'].isin(advanced_education)]
lower_education_rich_percentage = (without_higher_df['salary'] == '>50K').mean() * 100

# %%
higher_education_rich_percentage
# Out:
# 46.535843011613935

# %%
lower_education_rich_percentage
# Out:
# 17.3713601914639

# %%
# What is the minimum number of hours a person works per week (hours-per-week feature)
min_hours = df['hours-per-week'].min()

# %%
df['hours-per-week'].unique()
# Out:
# array([40, 13, 16, 45, 50, 80, 30, 35, 60, 20, 52, 44, 15, 25, 38, 43, 55,
#        48, 58, 32, 70,  2, 22, 56, 41, 28, 36, 24, 46, 42, 12, 65,  1, 10,
#        34, 75, 98, 33, 54,  8,  6, 64, 19, 18, 72,  5,  9, 47, 37, 21, 26,
#        14,  4, 59,  7, 99, 53, 39, 62, 57, 78, 90, 66, 11, 49, 84,  3, 17,
#        68, 27, 85, 31, 51, 77, 63, 23, 87, 88, 73, 89, 97, 94, 29, 96, 67,
#        82, 86, 91, 81, 76, 92, 61, 74, 95])

# %%
# What percentage of the people who work the minimum number of hours per week have a salary of >50K?
min_hours_df = df[df['hours-per-week'] == min_hours]

nun_min_workers = min_hours_df['salary'] == '>50K'


rich_percentage = percentage = (min_hours_df['salary'] == '>50K').mean() * 100

# %%
min_hours_df
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 189     58         State-gov  109567     Doctorate             16
# 1036    66      Self-emp-inc  150726           9th              5
# 1262    69                 ?  195779     Assoc-voc             11
# 5590    78                 ?  363134       HS-grad              9
# 5632    45                 ?  189564       Masters             14
# 5766    62                 ?   97231  Some-college             10
# 5808    76                 ?  211574          10th              6
# 8447    67                 ?  244122     Assoc-voc             11
# 9147    75                 ?  260543          10th              6
# 11451   27           Private  147951       HS-grad              9
# 19337   72                 ?   76860       HS-grad              9
# 19750   23           Private   72887       HS-grad              9
# 20072   65                 ?   76043       HS-grad              9
# ...

# %%
nun_min_workers
# Out:
# 189       True
# 1036     False
# 1262     False
# 5590     False
# 5632     False
# 5766     False
# 5808     False
# 8447     False
# 9147     False
# 11451    False
# 19337    False
# 19750    False
# 20072     True
# 20909    False
# 22960    False
# 23536    False
# 24284    False
# 25078    False
# 29752    False
# 32525    False
# Name: salary, dtype: bool

# %%
print(rich_percentage)
# Out:
# 10.0

# %%
  # What country has the highest percentage of people that earn >50K?
rich_df = df[df['salary'] == '>50K']
rich_df['native-country'].value_counts()
# Out:
# native-country
# United-States         7171
# ?                      146
# Philippines             61
# Germany                 44
# India                   40
# Canada                  39
# Mexico                  33
# England                 30
# Italy                   25
# Cuba                    25
# Japan                   24
# Taiwan                  20
# China                   20
# Iran                    18
# South                   16
# Puerto-Rico             12
# Poland                  12
# France                  12
# Jamaica                 10
# El-Salvador              9
# Greece                   8
# Cambodia                 7
# Hong                     6
# Yugoslavia               6
# Ireland                  5
# Vietnam                  5
# Portugal                 4
# Haiti                    4
# Ecuador                  4
# Thailand                 3
# Hungary                  3
# Guatemala                3
# Scotland                 3
# ...

# %%
rich_percentages = df[df['salary'] == '>50K']
country_percentages = rich_percentages['native-country'].value_counts() * 100

# %%
country_income_percentage = df[df['salary'] == '>50K']['native-country'].value_counts() / df['native-country'].value_counts()
country_income_percentage.idxmax()
# Out:
# 'Iran'

# %%
country_percentages
# Out:
# native-country
# United-States         717100
# ?                      14600
# Philippines             6100
# Germany                 4400
# India                   4000
# Canada                  3900
# Mexico                  3300
# England                 3000
# Italy                   2500
# Cuba                    2500
# Japan                   2400
# Taiwan                  2000
# China                   2000
# Iran                    1800
# South                   1600
# Puerto-Rico             1200
# Poland                  1200
# France                  1200
# Jamaica                 1000
# El-Salvador              900
# Greece                   800
# Cambodia                 700
# Hong                     600
# Yugoslavia               600
# Ireland                  500
# Vietnam                  500
# Portugal                 400
# Haiti                    400
# Ecuador                  400
# Thailand                 300
# Hungary                  300
# ...

# %%
# Filter the data for individuals with >50K salary and from India
high_income_df = df[df['salary'] == '>50K']
#india_high_income = high_income_df['native-country'] == 'India'
# Find the most popular occupation
#most_popular_occupation = india_high_income['occupation'].value_counts().idxmax()

# %%
india_high_income = high_income_df[high_income_df['native-country'] == 'India']
india_high_income
# Out:
#        age         workclass  fnlwgt    education  education-num  \
# 11      30         State-gov  141297    Bachelors             13
# 968     48           Private  164966    Bachelors             13
# 1327    52           Private  168381      HS-grad              9
# 7258    42         State-gov  102343  Prof-school             15
# 7285    54         State-gov   93449      Masters             14
# 8124    36           Private  172104  Prof-school             15
# 9939    43       Federal-gov  325706  Prof-school             15
# 10590   35           Private   98283  Prof-school             15
# 10661   59           Private  122283  Prof-school             15
# 10736   30           Private  243190  Prof-school             15
# 11260   54           Private  225599      Masters             14
# 11384   34           Private   98283  Prof-school             15
# 13422   53           Private  366957    Bachelors             13
# ...

# %%
india_high_income.value_counts()
# Out:
# native-country
# False    7801
# True       40
# Name: count, dtype: int64

# %%
country_income_percentage = df[df['salary'] == '>50K']['native-country'].value_counts() / df['native-country'].value_counts()
country_income_percentage
# Out:
# native-country
# ?                             0.250429
# Cambodia                      0.368421
# Canada                        0.322314
# China                         0.266667
# Columbia                      0.033898
# Cuba                          0.263158
# Dominican-Republic            0.028571
# Ecuador                       0.142857
# El-Salvador                   0.084906
# England                       0.333333
# France                        0.413793
# Germany                       0.321168
# Greece                        0.275862
# Guatemala                     0.046875
# Haiti                         0.090909
# Holand-Netherlands                 NaN
# Honduras                      0.076923
# Hong                          0.300000
# Hungary                       0.230769
# India                         0.400000
# Iran                          0.418605
# Ireland                       0.208333
# Italy                         0.342466
# ...
